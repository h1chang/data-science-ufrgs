# %% [markdown]
# Redes convolucionais no MNIST
#
# Primeiro: importar e normalizar o dataset

# %%
import tensorflow as tf
import time

mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255, x_test / 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Criar e preparar o modelo:

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(28, 28, 1)),    # 1 camada de convolução: 16 filtros 3x3
    tf.keras.layers.MaxPool2D((2,2)),                                                 # max pooling 2x2
    tf.keras.layers.Flatten(),                                                        # achatar p/ entrar em MLP
    tf.keras.layers.Dense(10, activation='softmax')                                   # 1 camada de saida com 10 neuronios
])

model.compile('adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 16)       0
#  )
#
#  flatten (Flatten)           (None, 2704)              0
#
#  dense (Dense)               (None, 10)                27050
#
# =================================================================
# Total params: 27,210
# Trainable params: 27,210
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Função para treinar e avaliar o modelo

# %%
def train_and_test(model, x_train, y_train, x_test, y_test, epocas=10): 
  # aqui vc vai dar start em um 'cronometro' pra medir o tempo gasto
  start = time.time()  # troque o 0 pelo comando que faz a tomada de tempo

  model.fit(x_train, y_train, epochs=epocas) # faz o treino do modelo

  # aqui vc vai paralizar o 'cronometro' e exibir o tempo gasto
  duration = time.time() - start  # troque o 0 pelo comando que faz a tomada de tempo
  
  print(f"Treinamento demorou {duration} segundos")
  
  print(f"Avaliação do modelo:")
  model.evaluate(x_test, y_test)

# %% [markdown]
# Vamos chamar a função para o modelo simples instanciado anteriormente

# %%
train_and_test(model, x_train, y_train, x_test, y_test, epocas=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 15s 2ms/step - loss: 0.2575 - accuracy: 0.9292
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0949 - accuracy: 0.9725
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0703 - accuracy: 0.9795
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0585 - accuracy: 0.9825
# Epoch 5/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0512 - accuracy: 0.9844
# Treinamento demorou 41.703229904174805 segundos
# Avaliação do modelo:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0594 - accuracy: 0.9815

# %% [markdown]
# **Ex01**: Mude o treinamento para 20 épocas. Verifique o tempo gasto para treinar e a acurácia final.

# %%
#seu codigo aqui
train_and_test(model, x_train, y_train, x_test, y_test, epocas=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0442 - accuracy: 0.9868
# Epoch 2/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0396 - accuracy: 0.9880
# Epoch 3/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0350 - accuracy: 0.9894
# Epoch 4/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0319 - accuracy: 0.9901
# Epoch 5/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0280 - accuracy: 0.9914
# Epoch 6/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0250 - accuracy: 0.9925
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0225 - accuracy: 0.9929
# Epoch 8/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0199 - accuracy: 0.9940
# Epoch 9/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0179 - accuracy: 0.9945
# Epoch 10/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0166 - accuracy: 0.9948
# Epoch 11/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0151 - accuracy: 0.9953
# Epoch 12/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0132 - accuracy: 0.9962
# Epoch 13/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0117 - accuracy: 0.9966
# Epoch 14/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0111 - accuracy: 0.9967
# Epoch 15/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 16/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0089 - accuracy: 0.9973
# Epoch 17/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0079 - accuracy: 0.9978
# Epoch 18/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0074 - accuracy: 0.9981
# Epoch 19/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0064 - accuracy: 0.9984
# Epoch 20/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0061 - accuracy: 0.9984
# Treinamento demorou 142.18351984024048 segundos
# Avaliação do modelo:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0768 - accuracy: 0.9821

# %% [markdown]
# **Ex01 - Resposta**:
#
# Treinamento demorou 142.24571061134338 segundos.
#
# Avaliação do modelo: loss: 0.0768 - accuracy: 0.9821

# %% [markdown]
# **Ex02:** Crie um modelo que atinja 99% de acurácia de teste em 20 ou menos épocas. Verifique o tempo gasto para treinar

# %%
# seu codigo aqui
model_2 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(128, (3,3), activation='relu', input_shape=(28, 28, 1)),    # 1 camada de convolução: 16 filtros 3x3
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),      
    tf.keras.layers.MaxPool2D((2,2)),                                                 # max pooling 2x2
    tf.keras.layers.Dropout(0.2),    
    tf.keras.layers.Flatten(),                              
    tf.keras.layers.Dense(128, activation=tf.nn.relu),      
    tf.keras.layers.Dropout(0.2),    
    tf.keras.layers.Dense(10, activation='softmax')                                   # 1 camada de saida com 10 neuronios

])

model_2.compile('adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_2.summary()

train_and_test(model_2, x_train, y_train, x_test, y_test, epocas=20)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 26, 26, 128)       1280
#
#  dropout_24 (Dropout)        (None, 26, 26, 128)       0
#
#  dense_33 (Dense)            (None, 26, 26, 256)       33024
#
#  max_pooling2d_13 (MaxPoolin  (None, 13, 13, 256)      0
#  g2D)
#
#  dropout_25 (Dropout)        (None, 13, 13, 256)       0
#
#  flatten_13 (Flatten)        (None, 43264)             0
#
#  dense_34 (Dense)            (None, 128)               5537920
#
#  dropout_26 (Dropout)        (None, 128)               0
#
#  dense_35 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 5,573,514
# Trainable params: 5,573,514
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1419 - accuracy: 0.9567
# Epoch 2/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0568 - accuracy: 0.9824
# Epoch 3/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0394 - accuracy: 0.9872
# Epoch 4/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0308 - accuracy: 0.9901
# Epoch 5/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0257 - accuracy: 0.9916
# Epoch 6/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0212 - accuracy: 0.9932
# Epoch 7/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0192 - accuracy: 0.9937
# Epoch 8/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0153 - accuracy: 0.9952
# Epoch 9/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0166 - accuracy: 0.9950
# Epoch 10/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0128 - accuracy: 0.9956
# Epoch 11/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0118 - accuracy: 0.9963
# Epoch 12/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0112 - accuracy: 0.9965
# Epoch 13/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0117 - accuracy: 0.9964
# Epoch 14/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0111 - accuracy: 0.9963
# Epoch 15/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0098 - accuracy: 0.9971
# Epoch 16/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0100 - accuracy: 0.9968
# Epoch 17/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0084 - accuracy: 0.9971
# Epoch 18/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0111 - accuracy: 0.9967
# Epoch 19/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0087 - accuracy: 0.9976
# Epoch 20/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0085 - accuracy: 0.9974
# Treinamento demorou 287.9270815849304 segundos
# Avaliação do modelo:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0679 - accuracy: 0.9890

# %% [markdown]
# Não consegui 99%, o melhor resultado foi abaixo:
#
# Treinamento demorou 287.9270815849304 segundos.
#
# Avaliação do modelo: loss: 0.0679 - accuracy: 0.9890

# %% [markdown]
# **Ex03:** Agora vamos fazer testes com o Fashion MNIST, um dataset um pouco mais dificil que o MNIST

# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist

# INICIO: coloque aqui o codigo para carregar e normalizar os dados do fashion mnist
(x_train_fashion, y_train_fashion),(x_test_fashion, y_test_fashion) = fashion_mnist.load_data()
x_train_fashion, x_test_fashion = x_train_fashion / 255, x_test_fashion / 255
# FIM: coloque aqui o codigo para carregar e normalizar os dados do fashion mnist

train_and_test(model, x_train_fashion, y_train_fashion, x_test_fashion, y_test_fashion, epocas=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.7034 - accuracy: 0.7890
# Epoch 2/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3990 - accuracy: 0.8595
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3479 - accuracy: 0.8774
# Epoch 4/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3172 - accuracy: 0.8878
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2960 - accuracy: 0.8936
# Epoch 6/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2791 - accuracy: 0.8995
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2650 - accuracy: 0.9041
# Epoch 8/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2530 - accuracy: 0.9091
# Epoch 9/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2427 - accuracy: 0.9132
# Epoch 10/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2331 - accuracy: 0.9166
# Treinamento demorou 45.85748100280762 segundos
# Avaliação do modelo:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3023 - accuracy: 0.8940

# %% [markdown]
# **Ex04:** Crie um modelo que atinja 90% de acurácia de teste no Fashion MNIST em 20 ou menos épocas. Você pode adicionar mais camadas convolucionais ou ocultas no multi-layer perceptron da saída. Verifique o tempo gasto para treinar.

# %%
# seu codigo aqui
model_4 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(28, 28, 1)),    # 1 camada de convolução: 16 filtros 3x3
    tf.keras.layers.Dense(128, activation=tf.nn.relu),  
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.MaxPool2D((2,2)),                                                 # max pooling 2x2
    tf.keras.layers.Flatten(),                                                        # achatar p/ entrar em MLP
    tf.keras.layers.Dense(128, activation=tf.nn.relu),  
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')                                   # 1 camada de saida com 10 neuronio

])

model_4.compile('adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model_4.summary()

train_and_test(model_4, x_train_fashion, y_train_fashion, x_test_fashion, y_test_fashion, epocas=15)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 26, 26, 16)        160
#
#  dense_12 (Dense)            (None, 26, 26, 128)       2176
#
#  dropout_6 (Dropout)         (None, 26, 26, 128)       0
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten_6 (Flatten)         (None, 21632)             0
#
#  dense_13 (Dense)            (None, 128)               2769024
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 2,772,650
# Trainable params: 2,772,650
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.3883 - accuracy: 0.8607
# Epoch 2/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2569 - accuracy: 0.9065
# Epoch 3/15
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2129 - accuracy: 0.9219
# Epoch 4/15
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1814 - accuracy: 0.9331
# Epoch 5/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1544 - accuracy: 0.9425
# Epoch 6/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1316 - accuracy: 0.9502
# Epoch 7/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1130 - accuracy: 0.9577
# Epoch 8/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0962 - accuracy: 0.9642
# Epoch 9/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0845 - accuracy: 0.9680
# Epoch 10/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0740 - accuracy: 0.9725
# Epoch 11/15
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0652 - accuracy: 0.9752
# Epoch 12/15
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0614 - accuracy: 0.9765
# Epoch 13/15
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0543 - accuracy: 0.9796
# Epoch 14/15
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0509 - accuracy: 0.9816
# Epoch 15/15
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0447 - accuracy: 0.9837
# Treinamento demorou 153.19458627700806 segundos
# Avaliação do modelo:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3525 - accuracy: 0.9223

# %% [markdown]
# Treinamento demorou 153.19458627700806 segundos
#
# Avaliação do modelo: loss: 0.3525 - accuracy: 0.9223
