# %% [markdown]
# # AD09 - GSOD 1929-Today Weather Dataset

# %% [markdown]
# # Introdução
#
# O conjunto de dados de teste tem origem aqui:
#
# - https://www.ncei.noaa.gov/access/metadata/landing-page/bin/iso?id=gov.noaa.ncdc:C00516
#
# Trata-se do conjunto de dados Global Summary of the Day (GSOD), com um sumário diário (frequentemente atualizado) de cerca de 9 mil estações metereológicas, entre os anos de 1929 até os dias de hoje. No conjunto de dados original, existe um arquivo por estação metereológica e por ano. As informações sobre cada coluna (e sua posição em bytes) pode ser consultado no link abaixo:
#
# - https://www.ncei.noaa.gov/data/global-summary-of-the-day/doc/readme.txt
#
# Há uma grande quantidade de arquivos, pelo menos 505 mil.
#
# ## Como baixar todos os arquivos
#
# Atenção, o código abaixo pode demorar pois o somatório do volume é de cerca de 3.2 GBytes. Para reduzir a quantidade de anos e obter dados mais rapidamente, basta alterar o código (onde aparece `1929` e `2022`). Perceba que os anos mais antigos tem uma quantidade de dados bem menor que anos recentes.

# %%
# %%bash
# BASE=https://www.ncei.noaa.gov/data/global-summary-of-the-day/archive/
# WD="weather"
# mkdir -p $WD
# pushd $WD
# for ano in $(seq 1929 1935); do
#     FILE=${ano}.tar.gz
#     wget -q $BASE/$FILE -O $FILE
#     tar vxfz $FILE
# done
# popd
# Out:
# /content/weather /content
# 03005099999.csv
# 03075099999.csv
# 03159099999.csv
# 03262099999.csv
# 03311099999.csv
# 03379099999.csv
# 03091099999.csv
# 03601099999.csv
# 03777099999.csv
# 03795099999.csv
# 03497099999.csv
# 03396099999.csv
# 03811099999.csv
# 03856099999.csv
# 03894099999.csv
# 03953099999.csv
# 03973099999.csv
# 03980099999.csv
# 99006199999.csv
# 03864099999.csv
# 03804099999.csv
# 03005099999.csv
# 03026099999.csv
# 03091099999.csv
# 03159099999.csv
# 03075099999.csv
# 03262099999.csv
# 03311099999.csv
# 03379099999.csv
# 03497099999.csv
# 03559099999.csv
# 03396099999.csv
# 03601099999.csv
# 03777099999.csv
# 03795099999.csv
# 03804099999.csv
# 03811099999.csv
# 03856099999.csv
# 03864099999.csv
# 03894099999.csv
# 03953099999.csv
# 03973099999.csv
# 99006199999.csv
# 03980099999.csv
# 03005099999.csv
# 03026099999.csv
# 03075099999.csv
# 03159099999.csv
# 03262099999.csv
# 03311099999.csv
# 03396099999.csv
# 03497099999.csv
# 03091099999.csv
# 03777099999.csv
# 03795099999.csv
# 03379099999.csv
# 03601099999.csv
# 03856099999.csv
# 03811099999.csv
# 03864099999.csv
# 03894099999.csv
# 03804099999.csv
# 03953099999.csv
# 03973099999.csv
# 03980099999.csv
# 10384099999.csv
# 10410099999.csv
# 10361099999.csv
# 10416099999.csv
# 10513099999.csv
# 12116099999.csv
# 12205099999.csv
# 26702099999.csv
# 72681024131.csv
# 99006199999.csv
# 03005099999.csv
# 03026099999.csv
# 03091099999.csv
# 03159099999.csv
# 03262099999.csv
# 03311099999.csv
# 03379099999.csv
# 03075099999.csv
# 03396099999.csv
# 28493099999.csv
# 28642099999.csv
# 28661099999.csv
# 28679099999.csv
# 28698099999.csv
# 28440099999.csv
# 26702099999.csv
# 28722099999.csv
# 28833099999.csv
# 29231099999.csv
# 29263099999.csv
# 29430099999.csv
# 29574099999.csv
# 29581099999.csv
# 29612099999.csv
# 29634099999.csv
# 29698099999.csv
# 29838099999.csv
# 29843099999.csv
# 29865099999.csv
# 29939099999.csv
# 30683099999.csv
# 30710099999.csv
# 30758099999.csv
# 30230099999.csv
# 31510099999.csv
# 30777099999.csv
# 31960099999.csv
# 31735099999.csv
# 32379099999.csv
# 32540099999.csv
# 34655099999.csv
# 34929099999.csv
# 35108099999.csv
# 30636099999.csv
# 32618099999.csv
# 35121099999.csv
# 35188099999.csv
# 35358099999.csv
# 35416099999.csv
# 35542099999.csv
# 35437099999.csv
# 35849099999.csv
# 36003099999.csv
# 35229099999.csv
# 36335099999.csv
# 36870099999.csv
# 37031099999.csv
# 35700099999.csv
# 37228099999.csv
# 36177099999.csv
# 37472099999.csv
# 37789099999.csv
# 37545099999.csv
# 37850099999.csv
# 38062099999.csv
# 38457099999.csv
# 38198099999.csv
# 37050099999.csv
# 38507099999.csv
# 38804099999.csv
# 38763099999.csv
# 38750099999.csv
# 38836099999.csv
# 38880099999.csv
# 38911099999.csv
# 38987099999.csv
# 72226513821.csv
# 72677024033.csv
# 72511514711.csv
# 78793099999.csv
# 72681024131.csv
# 72286023119.csv
# /content

# %% [markdown]
# ## Início

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ler e concatenar os dados oriundos de múltiplos arquivos
#
# Modifique os anos para ler somente um subconjunto de anos.

# %%
import os
import glob
all_files = glob.glob(os.path.join("weather/*.csv"))
df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
df
# Out:
#            STATION        DATE   LATITUDE  LONGITUDE  ELEVATION        NAME  \
# 0      36870099999  1935-05-01  43.233333  76.933333      851.0  ALMATY, KZ
# 1      36870099999  1935-05-03  43.233333  76.933333      851.0  ALMATY, KZ
# 2      36870099999  1935-05-04  43.233333  76.933333      851.0  ALMATY, KZ
# 3      36870099999  1935-05-05  43.233333  76.933333      851.0  ALMATY, KZ
# 4      36870099999  1935-05-06  43.233333  76.933333      851.0  ALMATY, KZ
# ...            ...         ...        ...        ...        ...         ...
# 28226  35416099999  1935-12-14  49.066667  54.683333      128.0     UIL, KZ
# 28227  35416099999  1935-12-17  49.066667  54.683333      128.0     UIL, KZ
# 28228  35416099999  1935-12-18  49.066667  54.683333      128.0     UIL, KZ
# 28229  35416099999  1935-12-23  49.066667  54.683333      128.0     UIL, KZ
# 28230  35416099999  1935-12-27  49.066667  54.683333      128.0     UIL, KZ
#
#        TEMP  TEMP_ATTRIBUTES    DEWP  DEWP_ATTRIBUTES  ...  MXSPD   GUST  \
# 0      60.0                4  9999.9                0  ...   13.0  999.9
# 1      54.5                4  9999.9                0  ...   13.0  999.9
# 2      53.7                4  9999.9                0  ...    8.9  999.9
# 3      66.7                4  9999.9                0  ...    5.1  999.9
# 4      67.0                4  9999.9                0  ...    8.9  999.9
# ...     ...              ...     ...              ...  ...    ...    ...
# 28226   7.0                4  9999.9                0  ...    1.9  999.9
# 28227  19.0                4  9999.9                0  ...   23.9  999.9
# 28228  16.7                4  9999.9                0  ...   23.9  999.9
# 28229  17.7                4  9999.9                0  ...   13.0  999.9
# 28230   5.0                4  9999.9                0  ...   43.9  999.9
#
#         MAX  MAX_ATTRIBUTES   MIN  MIN_ATTRIBUTES   PRCP  PRCP_ATTRIBUTES  \
# 0      75.0                  50.0               *  99.99
# 1      61.0                  48.0                   0.00                I
# 2      63.0               *  43.0               *   0.00                I
# 3      73.0                  46.0                   0.00                I
# 4      81.0                  52.0                   0.00                I
# ...     ...             ...   ...             ...    ...              ...
# 28226  18.0               *  -4.0               *   0.00                I
# 28227  25.0               *  14.0               *   0.00                I
# 28228  23.0               *  14.0               *   0.00                I
# 28229  27.0               *   7.0               *   0.00                I
# 28230  14.0               *   0.0               *   0.00                I
#
#         SNDP  FRSHTT
# 0      999.9   10000
# 1      999.9       0
# 2      999.9       0
# 3      999.9       0
# 4      999.9       0
# ...      ...     ...
# 28226  999.9       0
# 28227  999.9       0
# 28228  999.9       0
# 28229  999.9       0
# 28230  999.9       0
#
# [28231 rows x 28 columns]

# %% [markdown]
# ## Função para converter de Farenheit para Celcius

# %%
def fahrenheit_to_celsius (t_fahrenheit, r = 2):
    t_celsius = (5/9) * (t_fahrenheit - 32)
    t_celsius = round(t_celsius, r)
    return(t_celsius)

fahrenheit_to_celsius(100)
# Out:
# 37.78

# %% [markdown]
# # Exercícios
#
# Embora os dados tenham medidas em Farenheit, espera-se que as respostas sejam todas em Celcius. Utilize a função `fahrenheit_to_celsius` para converter uma coluna de temperatura em Farenheit para outra coluna em Celcius.

# %%
df["TEMP"] = fahrenheit_to_celsius(df["TEMP"])
df["MAX"] = fahrenheit_to_celsius(df["MAX"])
df["MIN"] = fahrenheit_to_celsius(df["MIN"])
df[["DATE", "TEMP", "MIN", "MAX"]]
# Out:
#              DATE   TEMP    MIN    MAX
# 0      1935-05-01  15.56  10.00  23.89
# 1      1935-05-03  12.50   8.89  16.11
# 2      1935-05-04  12.06   6.11  17.22
# 3      1935-05-05  19.28   7.78  22.78
# 4      1935-05-06  19.44  11.11  27.22
# ...           ...    ...    ...    ...
# 28226  1935-12-14 -13.89 -20.00  -7.78
# 28227  1935-12-17  -7.22 -10.00  -3.89
# 28228  1935-12-18  -8.50 -10.00  -5.00
# 28229  1935-12-23  -7.94 -13.89  -2.78
# 28230  1935-12-27 -15.00 -17.78 -10.00
#
# [28231 rows x 4 columns]

# %%
df
# Out:
#            STATION        DATE   LATITUDE  LONGITUDE  ELEVATION        NAME  \
# 0      36870099999  1935-05-01  43.233333  76.933333      851.0  ALMATY, KZ
# 1      36870099999  1935-05-03  43.233333  76.933333      851.0  ALMATY, KZ
# 2      36870099999  1935-05-04  43.233333  76.933333      851.0  ALMATY, KZ
# 3      36870099999  1935-05-05  43.233333  76.933333      851.0  ALMATY, KZ
# 4      36870099999  1935-05-06  43.233333  76.933333      851.0  ALMATY, KZ
# ...            ...         ...        ...        ...        ...         ...
# 28226  35416099999  1935-12-14  49.066667  54.683333      128.0     UIL, KZ
# 28227  35416099999  1935-12-17  49.066667  54.683333      128.0     UIL, KZ
# 28228  35416099999  1935-12-18  49.066667  54.683333      128.0     UIL, KZ
# 28229  35416099999  1935-12-23  49.066667  54.683333      128.0     UIL, KZ
# 28230  35416099999  1935-12-27  49.066667  54.683333      128.0     UIL, KZ
#
#         TEMP  TEMP_ATTRIBUTES    DEWP  DEWP_ATTRIBUTES  ...  MXSPD   GUST  \
# 0      15.56                4  9999.9                0  ...   13.0  999.9
# 1      12.50                4  9999.9                0  ...   13.0  999.9
# 2      12.06                4  9999.9                0  ...    8.9  999.9
# 3      19.28                4  9999.9                0  ...    5.1  999.9
# 4      19.44                4  9999.9                0  ...    8.9  999.9
# ...      ...              ...     ...              ...  ...    ...    ...
# 28226 -13.89                4  9999.9                0  ...    1.9  999.9
# 28227  -7.22                4  9999.9                0  ...   23.9  999.9
# 28228  -8.50                4  9999.9                0  ...   23.9  999.9
# 28229  -7.94                4  9999.9                0  ...   13.0  999.9
# 28230 -15.00                4  9999.9                0  ...   43.9  999.9
#
#          MAX  MAX_ATTRIBUTES    MIN  MIN_ATTRIBUTES   PRCP  PRCP_ATTRIBUTES  \
# 0      23.89                  10.00               *  99.99
# 1      16.11                   8.89                   0.00                I
# 2      17.22               *   6.11               *   0.00                I
# 3      22.78                   7.78                   0.00                I
# 4      27.22                  11.11                   0.00                I
# ...      ...             ...    ...             ...    ...              ...
# 28226  -7.78               * -20.00               *   0.00                I
# 28227  -3.89               * -10.00               *   0.00                I
# 28228  -5.00               * -10.00               *   0.00                I
# 28229  -2.78               * -13.89               *   0.00                I
# 28230 -10.00               * -17.78               *   0.00                I
#
#         SNDP  FRSHTT
# 0      999.9   10000
# 1      999.9       0
# 2      999.9       0
# 3      999.9       0
# 4      999.9       0
# ...      ...     ...
# 28226  999.9       0
# 28227  999.9       0
# 28228  999.9       0
# 28229  999.9       0
# 28230  999.9       0
#
# [28231 rows x 28 columns]

# %% [markdown]
# ## Resposta estas questões

# %% [markdown]
# Qual a temperatura máxima?

# %%
df["TEMP"].max()
# Out:
# 37.5

# %% [markdown]
# Qual a temperatura máxima por ano?

# %%
df[['Ano','Mes','Dia']] = df.DATE.str.split("-",expand=True,)
df.groupby("Ano")["TEMP"].max()
# Out:
# Ano
# 1930    15.28
# 1932    26.67
# 1933    11.00
# 1934    24.28
# 1935    37.50
# Name: TEMP, dtype: float64

# %% [markdown]
# Qual a temperatura média por mês, de cada ano?

# %%
df[['Ano','Mes','Dia']] = df.DATE.str.split("-",expand=True,)
df.groupby(["Ano", "Mes"])["TEMP"].mean()
# Out:
# Ano   Mes
# 1930  06     15.280000
# 1932  01     12.582097
#       02      9.730690
#       03     11.865410
#       04     10.981220
#       05     26.132000
#       06     26.520000
#       07     25.846000
#       08     25.334000
#       09     26.266111
#       11     19.522000
#       12     16.832857
# 1933  01      0.851319
#       02      0.329881
#       03      7.199841
#       04      8.938750
# 1934  01    -13.606429
#       02    -12.030909
#       03    -10.367692
#       04     -2.043846
#       05      9.955937
#       06     16.227000
#       07     16.096061
#       08     16.762581
#       09      6.922581
#       10      3.836970
#       11     -7.012593
#       12    -13.413704
# 1935  01      2.051698
#       02      3.721678
#       03      4.682202
#       04      8.294996
#       05     11.556325
#       06     17.144808
#       07     19.050285
#       08     18.413135
#       09     13.741417
#       10      8.163127
#       11      0.365285
#       12     -1.978181
# Name: TEMP, dtype: float64

# %% [markdown]
# Qual o dia do ano mais quente?

# %%
df[['Ano','Mes','Dia']] = df.DATE.str.split("-",expand=True,)
df.groupby(["Dia"])["TEMP"].max().sort_values(ascending=False).index[0]
# Out:
# '05'

# %% [markdown]
# Em um dado ano, qual a temperatura máxima por estação metereológica?

# %%
df[['Ano','Mes','Dia']] = df.DATE.str.split("-",expand=True,)
df.groupby(["Ano", "STATION"])["TEMP"].max()
# Out:
# Ano   STATION
# 1930  3559099999     15.28
# 1932  3811099999     12.06
#       99006199999    26.67
# 1933  3379099999     11.00
#       3864099999     10.56
#                      ...
# 1935  72286023119    36.22
#       72511514711    32.11
#       72677024033    32.94
#       72681024131    32.83
#       78793099999    27.22
# Name: TEMP, Length: 153, dtype: float64

# %% [markdown]
# Quantas estações existem em cada ano?

# %%
df[['Ano','Mes','Dia']] = df.DATE.str.split("-",expand=True,)
df.groupby(["Ano", "STATION"]).size()
# Out:
# Ano   STATION
# 1930  3559099999       1
# 1932  3811099999     121
#       99006199999    175
# 1933  3379099999      89
#       3864099999      97
#                     ...
# 1935  72286023119    365
#       72511514711    242
#       72677024033    215
#       72681024131    365
#       78793099999      5
# Length: 153, dtype: int64

# %% [markdown]
# Qual a maior amplitude de temperatura para um dado dia?

# %%
df[['Ano','Mes','Dia']] = df.DATE.str.split("-",expand=True,)
dft = df[["Ano", "Mes", "Dia", "TEMP"]] \
    .groupby(["Ano", "Mes", "Dia"], as_index=False) \
    .agg({"TEMP": [min, max]})
#dft.reset_index(inplace=True)
dft.columns = ["_".join(x) for x in dft.columns.ravel()]
dft["amplitude"] = dft["TEMP_max"] - dft["TEMP_min"]
dft.sort_values("amplitude", ascending=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#      Ano_ Mes_ Dia_  TEMP_min  TEMP_max  amplitude
# 873  1935   11   23    -44.00     18.50      62.50
# 862  1935   11   12    -41.67     20.28      61.95
# 901  1935   12   21    -31.28     26.94      58.22
# 906  1935   12   26    -41.78     14.61      56.39
# 904  1935   12   24    -37.78     17.28      55.06
# ..    ...  ...  ...       ...       ...        ...
# 404  1934   06   25     15.28     15.28       0.00
# 405  1934   06   26     15.83     15.83       0.00
# 408  1934   06   29     17.50     17.50       0.00
# 409  1934   06   30     16.94     16.94       0.00
# 0    1930   06   24     15.28     15.28       0.00
#
# [912 rows x 6 columns]

# %% [markdown]
# Existem casos onde a temperatura MIN é maior que a MAX?

# %%
df[['Ano','Mes','Dia']] = df.DATE.str.split("-",expand=True,)
dft = df[["Ano", "Mes", "Dia", "TEMP"]] \
    .groupby(["Ano", "Mes", "Dia"], as_index=False) \
    .agg({"TEMP": [min, max]})
#dft.reset_index(inplace=True)
dft.columns = ["_".join(x) for x in dft.columns.ravel()]
dft[dft["TEMP_max"] < dft["TEMP_min"]]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
# Empty DataFrame
# Columns: [Ano_, Mes_, Dia_, TEMP_min, TEMP_max]
# Index: []
